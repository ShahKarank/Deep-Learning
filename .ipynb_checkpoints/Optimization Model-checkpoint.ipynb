# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN','NAME'])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
unq = application_df.nunique()
unq
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
atype = application_df['APPLICATION_TYPE'].value_counts()
atype
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(atype[atype < 400].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
csf = application_df['CLASSIFICATION'].value_counts()
csf
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2190        1
# C8210        1
# C5200        1
# C1732        1
# C1820        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
ref= csf.head(45)
ref
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C1720        6
# C2400        6
# C1257        5
# C1600        5
# C1260        3
# C0           3
# C2710        3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(csf[csf < 200].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1197
# C7000      777
# C1700      287
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
num = pd.get_dummies(application_df)
num
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = num['IS_SUCCESSFUL'].values
X = num.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
#Adding 3 more additional nodes

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

i_f = len(X_train_scaled[0])
h_n1 = 16
h_n2 = 16
h_n3 = 16
h_n4 = 16
h_n5 = 16

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=h_n1, activation='relu', input_dim=i_f))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=h_n2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=h_n3, activation='relu'))

# fourth hidden layer
nn.add(tf.keras.layers.Dense(units=h_n4, activation='relu'))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=h_n5, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\krazy\.conda\envs\pythondata\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 16)                736
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# ...

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\krazy\.conda\envs\pythondata\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train the model
f_m = nn.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 25724/25724 [==============================] - 1s 29us/sample - loss: 0.5889 - acc: 0.6979
# Epoch 2/30
# 25724/25724 [==============================] - 1s 23us/sample - loss: 0.5562 - acc: 0.7267
# Epoch 3/30
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5533 - acc: 0.7276
# Epoch 4/30
# 25724/25724 [==============================] - 1s 23us/sample - loss: 0.5512 - acc: 0.7303
# Epoch 5/30
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5496 - acc: 0.7317
# Epoch 6/30
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5492 - acc: 0.7310
# Epoch 7/30
# 25724/25724 [==============================] - 1s 25us/sample - loss: 0.5480 - acc: 0.7313
# Epoch 8/30
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5479 - acc: 0.7331
# Epoch 9/30
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5466 - acc: 0.73360s - loss: 0.5477 - acc: 0.73
# Epoch 10/30
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5535 - acc: 0.7301
# Loss: 0.5534746609137288, Accuracy: 0.7301457524299622

# %%
# Export our model to HDF5 file
nn.save('Models/Alphabet2.h5')

# %%
#Removing 1 Hidden Layer and increasing epochs

# %%
i_f = len(X_train_scaled[0])
h_n1 = 16
h_n2 = 16
h_n3 = 16
h_n4 = 16


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=h_n1, activation='relu', input_dim=i_f))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=h_n2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=h_n3, activation='relu'))

# fourth hidden layer
nn.add(tf.keras.layers.Dense(units=h_n4, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 16)                736
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 17
# ...
# Total params: 1,569
# Trainable params: 1,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
f_m = nn.fit(X_train_scaled, y_train, epochs=35)
# Out:
# Epoch 1/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5848 - acc: 0.7096
# Epoch 2/35
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5583 - acc: 0.7268
# Epoch 3/35
# 25724/25724 [==============================] - 1s 22us/sample - loss: 0.5541 - acc: 0.7273
# Epoch 4/35
# 25724/25724 [==============================] - 1s 22us/sample - loss: 0.5525 - acc: 0.7304
# Epoch 5/35
# 25724/25724 [==============================] - 1s 23us/sample - loss: 0.5505 - acc: 0.73060s - loss: 0.5528 - acc:
# Epoch 6/35
# 25724/25724 [==============================] - 1s 25us/sample - loss: 0.5496 - acc: 0.7308
# Epoch 7/35
# 25724/25724 [==============================] - 1s 25us/sample - loss: 0.5490 - acc: 0.7309
# Epoch 8/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5478 - acc: 0.7312
# Epoch 9/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5478 - acc: 0.7325
# Epoch 10/35
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5513 - acc: 0.7317
# Loss: 0.5512794763423263, Accuracy: 0.7316617965698242

# %%
# Export our model to HDF5 file
nn.save('Models/Alphabet3.h5')

# %%
 #Further increasing Epochs

# %%
i_f = len(X_train_scaled[0])
h_n1 = 16
h_n2 = 16
h_n3 = 16
h_n4 = 32


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=h_n1, activation='relu', input_dim=i_f))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=h_n2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=h_n3, activation='relu'))

# fourth hidden layer
nn.add(tf.keras.layers.Dense(units=h_n4, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 16)                736
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 33
# ...
# Total params: 1,857
# Trainable params: 1,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
f_m = nn.fit(X_train_scaled, y_train, epochs=40)
# Out:
# Epoch 1/40
# 25724/25724 [==============================] - 1s 28us/sample - loss: 0.5843 - acc: 0.7060
# Epoch 2/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5565 - acc: 0.7286
# Epoch 3/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5525 - acc: 0.7293
# Epoch 4/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5505 - acc: 0.7302
# Epoch 5/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5489 - acc: 0.7307
# Epoch 6/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5483 - acc: 0.7316
# Epoch 7/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5471 - acc: 0.7308
# Epoch 8/40
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5460 - acc: 0.7326
# Epoch 9/40
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5465 - acc: 0.7326
# Epoch 10/40
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5526 - acc: 0.7275
# Loss: 0.5525962364013272, Accuracy: 0.7274635434150696

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('Models/AlphabetSoupCharity4.h5')

# %%
#Previous one was better so reverting changes and trying different activaton functions

# %%
i_f = len(X_train_scaled[0])
h_n1 = 16
h_n2 = 16
h_n3 = 16
h_n4 = 16


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=h_n1, activation='tanh', input_dim=i_f))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=h_n2, activation='tanh'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=h_n3, activation='tanh'))

# fourth hidden layer
nn.add(tf.keras.layers.Dense(units=h_n4, activation='tanh'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 16)                736
# _________________________________________________________________
# dense_17 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_18 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 17
# ...
# Total params: 1,569
# Trainable params: 1,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
f_m = nn.fit(X_train_scaled, y_train, epochs=35)
# Out:
# Epoch 1/35
# 25724/25724 [==============================] - 1s 29us/sample - loss: 0.5767 - acc: 0.7143
# Epoch 2/35
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5573 - acc: 0.7255
# Epoch 3/35
# 25724/25724 [==============================] - 1s 25us/sample - loss: 0.5539 - acc: 0.7266
# Epoch 4/35
# 25724/25724 [==============================] - 1s 24us/sample - loss: 0.5517 - acc: 0.7277
# Epoch 5/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5505 - acc: 0.7289
# Epoch 6/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5494 - acc: 0.7297
# Epoch 7/35
# 25724/25724 [==============================] - 1s 27us/sample - loss: 0.5485 - acc: 0.7301
# Epoch 8/35
# 25724/25724 [==============================] - 1s 26us/sample - loss: 0.5479 - acc: 0.73100s - loss: 0.5758 - acc: 0.708 - ETA: 0s - loss: 0.5617 - a - ETA: 0s - loss: 0.5452 - acc: 0.73
# Epoch 9/35
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5528 - acc: 0.7314
# Loss: 0.5527676092639956, Accuracy: 0.7314285635948181

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('Models/AlphabetSoupCharity4.h6')
